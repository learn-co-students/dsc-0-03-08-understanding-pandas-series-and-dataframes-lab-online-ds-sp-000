# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 11 columns):
# C/A                                                                     197625 non-null object
# UNIT                                                                    197625 non-null object
# SCP                                                                     197625 non-null object
# STATION                                                                 197625 non-null object
# LINENAME                                                                197625 non-null object
# DIVISION                                                                197625 non-null object
# DATE                                                                    197625 non-null object
# TIME                                                                    197625 non-null object
# DESC                                                                    197625 non-null object
# ...

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
df.columns = map(str.lower, df.columns)
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#Your code here
df.set_index('linename', inplace = True) # inplace = True makes change permanent
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %%
df.index.unique() # shows all unique linenames
# Out:
# Index(['NQR456W', 'NQRW', 'ACENQRS1237W', 'BDFMNQRW', 'NRW', 'LNQR456W',
#        'JNQRZ6W', 'RNW', 'R1W', 'FJMZ',
#        ...
#        '7', '7NQW', 'NQW', '7EFMR', '2345R', '2345', '2345BDNQR', '2345S',
#        '34', '5'],
#       dtype='object', name='linename', length=113)

# %%
df.loc['7EFMR'] # to locate and list lines with unique code from index, remember to use brackets
# Out:
#            c/a  unit       scp         station division        date      time  \
# linename
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  00:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  04:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  08:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  12:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  16:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/25/2018  20:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  00:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  04:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  08:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  12:00:00
# 7EFMR     R525  R018  02-00-00  74 ST-BROADWAY      IRT  08/26/2018  16:00:00
# ...

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
df.reset_index(inplace = True)
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
unique_linenames = df.groupby('station')['linename'].nunique()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
df['Num_Line'] = unique_linenames

# %%
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Line
# 0       NaN
# 1       NaN
# 2       NaN
# ...

# %%
df.sort_values(by = ['Num_Line'], inplace = True, ascending = False)

# %%
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Line
# 0       NaN
# 1       NaN
# 2       NaN
# ...

# %%
df.tail(10)
# Out:
#        linename    c/a  unit       scp        station division        date  \
# 197615        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197616        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197617        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197618        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018
# 197619        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197620        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197621        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197622        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197623        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197624        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
#
#             time     desc  entries  \
# 197615  09:00:00  REGULAR     5554
# 197616  13:00:00  REGULAR     5554
# ...

# %% [markdown]
# ## Write a function to clean a column name.

# %%
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'Num_Line'],
#       dtype='object')

# %%
def clean(col_name):
    cleaned = col_name.strip()
    #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'Num_Line'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
df.head()
#Your code here
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries    exits  Num_Line
# 0  REGULAR  6736067  2283184       NaN
# 1  REGULAR  6736087  2283188       NaN
# 2  REGULAR  6736105  2283229       NaN
# 3  REGULAR  6736180  2283314       NaN
# 4  REGULAR  6736349  2283384       NaN

# %%
df.dtypes
# Out:
# linename     object
# c/a          object
# unit         object
# scp          object
# station      object
# division     object
# date         object
# time         object
# desc         object
# entries       int64
# exits         int64
# Num_Line    float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# linename            object
# c/a                 object
# unit                object
# scp                 object
# station             object
# division            object
# date        datetime64[ns]
# time                object
# desc                object
# entries              int64
# exits                int64
# Num_Line           float64
# dtype: object

# %%
df['day_of_the_week'] = df['date'].dt.day_name()

# %%
df.head()
# Out:
#   linename   c/a  unit       scp station division       date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  Num_Line day_of_the_week
# 0  REGULAR  6736067  2283184       NaN        Saturday
# 1  REGULAR  6736087  2283188       NaN        Saturday
# 2  REGULAR  6736105  2283229       NaN        Saturday
# 3  REGULAR  6736180  2283314       NaN        Saturday
# 4  REGULAR  6736349  2283384       NaN        Saturday

# %%
plt.style.use('ggplot')
plt.xkcd()
day_order = ['Sunday','Saturday','Friday','Thursday','Wednesday','Tuesday','Monday']
df.groupby('day_of_the_week')['entries'].mean().loc[day_order].plot(kind = 'barh', figsize = (8,6), color = '#ccff00')
plt.ylabel("")
plt.xlabel("Number of Entries", fontsize = 14)
plt.title("Number of Entries by Day of the Week", fontsize = 14)
plt.tight_layout()
plt.savefig('subway_plot')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
def is_weekend(column):
    if(column == 'Saturday') | (column == 'Sunday'):
        return 1
    else:
        return 0
#Your code here

# %%
df['weekend'] = df['day_of_the_week'].map(is_weekend)

# %%
df.head()
# Out:
#   linename   c/a  unit       scp station division       date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  Num_Line day_of_the_week  weekend
# 0  REGULAR  6736067  2283184       NaN        Saturday        1
# 1  REGULAR  6736087  2283188       NaN        Saturday        1
# 2  REGULAR  6736105  2283229       NaN        Saturday        1
# 3  REGULAR  6736180  2283314       NaN        Saturday        1
# 4  REGULAR  6736349  2283384       NaN        Saturday        1

# %%
df.groupby('weekend')['entries'].mean()
# Out:
# weekend
# 0    3.959848e+07
# 1    4.132588e+07
# Name: entries, dtype: float64

# %%
my_plot = df.groupby('weekend')['entries'].mean().plot(kind = 'barh', figsize = (8,6))
my_plot.set_yticklabels(["Not Weekend", "Weekend"])
plt.ylabel('')
plt.xlabel('Number of Entries')
plt.title('Number of Entries Weekend vs. Not Weekend')
# Out:
# Text(0.5,1,'Number of Entries Weekend vs. Not Weekend')

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
df.head()
# Out:
#   linename   c/a  unit       scp station division       date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  Num_Line day_of_the_week  weekend
# 0  REGULAR  6736067  2283184       NaN        Saturday        1
# 1  REGULAR  6736087  2283188       NaN        Saturday        1
# 2  REGULAR  6736105  2283229       NaN        Saturday        1
# 3  REGULAR  6736180  2283314       NaN        Saturday        1
# 4  REGULAR  6736349  2283384       NaN        Saturday        1

# %%
df.drop(['division','c/a'], axis = 1, inplace = True) # axis 1 is for column 0 is for row

# %%
df.head()
# Out:
#   linename  unit       scp station       date      time     desc  entries  \
# 0  NQR456W  R051  02-00-00   59 ST 2018-08-25  00:00:00  REGULAR  6736067
# 1  NQR456W  R051  02-00-00   59 ST 2018-08-25  04:00:00  REGULAR  6736087
# 2  NQR456W  R051  02-00-00   59 ST 2018-08-25  08:00:00  REGULAR  6736105
# 3  NQR456W  R051  02-00-00   59 ST 2018-08-25  12:00:00  REGULAR  6736180
# 4  NQR456W  R051  02-00-00   59 ST 2018-08-25  16:00:00  REGULAR  6736349
#
#      exits  Num_Line day_of_the_week  weekend
# 0  2283184       NaN        Saturday        1
# 1  2283188       NaN        Saturday        1
# 2  2283229       NaN        Saturday        1
# 3  2283314       NaN        Saturday        1
# 4  2283384       NaN        Saturday        1
